# %%
# create a simple white noise with increasing variance
from random import gauss
from random import seed
from matplotlib import pyplot
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# plot
pyplot.plot(data)
pyplot.show()

# %%
# check correlations of squared observations
from random import gauss
from random import seed
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
import pandas as pd
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# square the dataset
squared_data = pd.Series(x**2 for x in data)
# create acf plot
plot_acf(squared_data)
pyplot.show()

# %%
# example of ARCH model
from random import gauss
from random import seed
from matplotlib import pyplot
from arch import arch_model
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# split into train/test
n_test = 10
train, test = data[:-n_test], data[-n_test:]
# define model
model = arch_model(train, mean='Zero', vol='ARCH', p=15)
# fit model
model_fit = model.fit()
# forecast the test set
yhat = model_fit.forecast(horizon=n_test)
# plot the actual variance
var = [i*0.01 for i in range(0,100)]
pyplot.plot(var[-n_test:])
# plot forecast variance
pyplot.plot(yhat.variance.values[-1, :])
pyplot.show()
# Out:
# Iteration:      1,   Func. Count:     18,   Neg. LLF: 41.42285909902891
# Iteration:      2,   Func. Count:     37,   Neg. LLF: 38.58236083357411
# Iteration:      3,   Func. Count:     56,   Neg. LLF: 36.7085763087076
# Iteration:      4,   Func. Count:     75,   Neg. LLF: 35.643299535905854
# Iteration:      5,   Func. Count:     94,   Neg. LLF: 34.388550594271955
# Iteration:      6,   Func. Count:    113,   Neg. LLF: 31.60311898661349
# Iteration:      7,   Func. Count:    132,   Neg. LLF: 30.18000495649996
# Iteration:      8,   Func. Count:    150,   Neg. LLF: 28.719725486262355
# Iteration:      9,   Func. Count:    169,   Neg. LLF: 25.763847807600783
# Iteration:     10,   Func. Count:    189,   Neg. LLF: 25.732448158375743
# Iteration:     11,   Func. Count:    208,   Neg. LLF: 25.649898400949965
# Iteration:     12,   Func. Count:    227,   Neg. LLF: 25.560400174962492
# Iteration:     13,   Func. Count:    247,   Neg. LLF: 25.546556864411116
# Iteration:     14,   Func. Count:    266,   Neg. LLF: 25.488553214799353
# Iteration:     15,   Func. Count:    285,   Neg. LLF: 25.484752314536735
# Iteration:     16,   Func. Count:    304,   Neg. LLF: 25.48361367718935
# Iteration:     17,   Func. Count:    323,   Neg. LLF: 25.48293021570813
# Iteration:     18,   Func. Count:    341,   Neg. LLF: 25.482149550871984
# Iteration:     19,   Func. Count:    359,   Neg. LLF: 25.480673704475088
# Iteration:     20,   Func. Count:    377,   Neg. LLF: 25.47836305072897
# Iteration:     21,   Func. Count:    395,   Neg. LLF: 25.477639112276965
# Iteration:     22,   Func. Count:    413,   Neg. LLF: 25.477510520009194
# Iteration:     23,   Func. Count:    431,   Neg. LLF: 25.47750761026963
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 25.477507643946026
#             Iterations: 23
#             Function evaluations: 431
#             Gradient evaluations: 23
# /Users/singhhim1/anaconda3/envs/ADP/lib/python3.7/site-packages/arch/univariate/base.py:260: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.2709. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   DataScaleWarning)

# %%
# example of ARCH model
from random import gauss
from random import seed
from matplotlib import pyplot
from arch import arch_model
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# split into train/test
n_test = 10
train, test = data[:-n_test], data[-n_test:]
# define model
model = arch_model(train, mean='Zero', vol='GARCH', p=15, q=15)
# fit model
model_fit = model.fit()
# forecast the test set
yhat = model_fit.forecast(horizon=n_test)
# plot the actual variance
var = [i*0.01 for i in range(0,100)]
pyplot.plot(var[-n_test:])
# plot forecast variance
pyplot.plot(yhat.variance.values[-1, :])
pyplot.show()
# Out:
# /Users/singhhim1/anaconda3/envs/ADP/lib/python3.7/site-packages/arch/univariate/base.py:260: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.2709. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   DataScaleWarning)
# Iteration:      1,   Func. Count:     33,   Neg. LLF: 50.22157561649052
# Iteration:      2,   Func. Count:     71,   Neg. LLF: 49.70879553327739
# Iteration:      3,   Func. Count:    105,   Neg. LLF: 46.96601176103537
# Iteration:      4,   Func. Count:    139,   Neg. LLF: 43.150024517372856
# Iteration:      5,   Func. Count:    173,   Neg. LLF: 40.82899268368657
# Iteration:      6,   Func. Count:    207,   Neg. LLF: 38.992364151451255
# Iteration:      7,   Func. Count:    241,   Neg. LLF: 35.11219533540187
# Iteration:      8,   Func. Count:    275,   Neg. LLF: 30.85724746957339
# Iteration:      9,   Func. Count:    309,   Neg. LLF: 29.78736306351841
# Iteration:     10,   Func. Count:    343,   Neg. LLF: 28.255388580423677
# Iteration:     11,   Func. Count:    376,   Neg. LLF: 26.957522993799014
# Iteration:     12,   Func. Count:    411,   Neg. LLF: 26.71517755358051
# Iteration:     13,   Func. Count:    445,   Neg. LLF: 26.284834539761505
# Iteration:     14,   Func. Count:    479,   Neg. LLF: 25.972394156802054
# Iteration:     15,   Func. Count:    513,   Neg. LLF: 25.84075196581814
# Iteration:     16,   Func. Count:    547,   Neg. LLF: 25.62883657733098
# Iteration:     17,   Func. Count:    580,   Neg. LLF: 25.516070098539906
# Iteration:     18,   Func. Count:    614,   Neg. LLF: 25.49935626575277
# Iteration:     19,   Func. Count:    648,   Neg. LLF: 25.49424842654186
# Iteration:     20,   Func. Count:    681,   Neg. LLF: 25.492111972333873
# Iteration:     21,   Func. Count:    714,   Neg. LLF: 25.48542043982475
# Iteration:     22,   Func. Count:    747,   Neg. LLF: 25.47968355228038
# Iteration:     23,   Func. Count:    780,   Neg. LLF: 25.477821929876765
# Iteration:     24,   Func. Count:    813,   Neg. LLF: 25.477525486701296
# Iteration:     25,   Func. Count:    846,   Neg. LLF: 25.477511569503726
# Iteration:     26,   Func. Count:    879,   Neg. LLF: 25.477507907715825
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 25.477507944732444
#             Iterations: 26
#             Function evaluations: 879
#             Gradient evaluations: 26
