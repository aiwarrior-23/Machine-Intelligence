# %%
# PCA

# %%
from sklearn.datasets import load_digits

digits = load_digits()

digits.data.shape
# Out:
# (1797, 64)

# %%
from sklearn.decomposition import PCA

pca = PCA(2)  # project from 64 to 2 dimensions

projected = pca.fit_transform(digits.data)

print(digits.data.shape)
print(projected.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.14890594, 0.13618771])

# %%
import matplotlib.pyplot as plt

plt.scatter(projected[:, 0], projected[:, 1], c=digits.target, alpha=0.5)
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();

# %%
pca.components_
# Out:
# array([[ 4.42725902e-17, -1.73094639e-02, -2.23428827e-01,
#         -1.35913309e-01, -3.30323174e-02, -9.66340823e-02,
#         -8.32943442e-03,  2.26900122e-03, -3.20516504e-04,
#         -1.19308902e-01, -2.44451674e-01,  1.48512742e-01,
#         -4.67319424e-02, -2.17740745e-01, -1.48136740e-02,
#          4.47779542e-03, -4.94136623e-05, -7.95419366e-02,
#          8.33951473e-02,  2.15915343e-01, -1.72126801e-01,
#         -1.63712096e-01,  2.86444477e-02,  4.23251810e-03,
#          9.85488459e-05,  6.42319137e-02,  2.54093319e-01,
#         -3.56771028e-02, -2.09462569e-01, -4.31311341e-02,
#          5.13118705e-02,  2.13422736e-04, -0.00000000e+00,
#          1.59950884e-01,  3.68690777e-01,  1.64406828e-01,
#          8.52007924e-02,  3.72982878e-02,  2.15866959e-02,
#         -0.00000000e+00,  1.28865588e-03,  1.06945288e-01,
#          3.03067458e-01,  2.47813044e-01,  2.09637300e-01,
#          1.22325242e-02, -3.69458534e-02,  1.61485023e-03,
#          6.93023560e-04, -8.35144070e-03, -5.58598930e-02,
#          9.30534159e-02,  1.07387722e-01, -1.37734562e-01,
#         -6.32879441e-02,  9.61671474e-04,  9.55079223e-06,
#         -1.40786826e-02, -2.35675479e-01, -1.41225595e-01,
#         -9.15965090e-03, -8.94184621e-02, -3.65977054e-02,
#         -1.14684942e-02],
#        [ 2.95577040e-17, -1.01064708e-02, -4.90850052e-02,
#         -9.43335294e-03, -5.36015128e-02, -1.17755317e-01,
#         -6.21281903e-02, -7.93574673e-03, -1.63216340e-04,
#         -2.10167446e-02,  6.03485591e-02, -5.33766744e-03,
#         -9.19769457e-02, -5.19210453e-02, -5.89354846e-02,
#         -3.33283584e-03, -4.22870951e-05,  3.62458302e-02,
#          1.98257357e-01, -4.86386491e-02, -2.25574875e-01,
#         -4.50545375e-03,  2.67696371e-02, -2.08737667e-04,
#         -5.66233177e-05,  7.71235148e-02,  1.88447072e-01,
#         -1.37952529e-01, -2.61042729e-01,  4.98349650e-02,
#          6.51113280e-02,  4.03199496e-05, -0.00000000e+00,
#          8.81559953e-02,  8.71736935e-02, -2.70860251e-01,
#         -2.85291799e-01,  1.66461585e-01,  1.27860554e-01,
#         -0.00000000e+00,  2.89440169e-04,  5.08305017e-02,
#          1.30274482e-01, -2.68906496e-01, -3.01575576e-01,
#          2.40259059e-01,  2.17555582e-01,  1.32726080e-03,
#          2.86743020e-04,  1.05548258e-02,  1.53370684e-01,
#         -1.19535168e-01, -9.72508415e-02,  2.85869476e-01,
#          1.48776414e-01,  5.42284034e-04, -3.34027883e-05,
#         -1.00791299e-02, -7.02724938e-02,  1.71108640e-02,
#          1.94296430e-01,  1.76697052e-01,  1.94546458e-02,
#         -6.69695478e-03]])
